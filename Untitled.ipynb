# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("aufgabe1_performance.csv", sep=";")
df.head()
# Out:
#    amount_of_polygons  execution_time_in_seconds
# 0                   1                   0.000250
# 1                   2                   0.000994
# 2                   3                   0.001879
# 3                   4                   0.002036
# 4                   5                   0.004085

# %%
plt.title("Laufzeitanalyse Aufgabe1")
plt.xlabel("Anzahl an Polygonen")
plt.ylabel("Programmlaufzeit in Sekunden")
plt.scatter(df["amount_of_polygons"],df["execution_time_in_seconds"])
plt.savefig("aufgabe1_laufzeit_graph.png")

# %%
df
# Out:
#     amount_of_polygons  execution_time_in_seconds
# 0                    1                   0.000250
# 1                    2                   0.000994
# 2                    3                   0.001879
# 3                    4                   0.002036
# 4                    5                   0.004085
# 5                    6                   0.009401
# 6                    7                   0.014252
# 7                    8                   0.021608
# 8                    9                   0.026869
# 9                   10                   0.040748
# 10                  11                   0.038870
# 11                  12                   0.057334
# 12                  13                   0.068762
# 13                  14                   0.089569
# 14                  15                   0.117132
# 15                  16                   0.121385
# 16                  17                   0.173183
# 17                  18                   0.195476
# ...
